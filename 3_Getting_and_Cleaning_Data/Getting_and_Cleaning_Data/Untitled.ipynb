# %%
import pandas as pd
import numpy as np

# %%
melbourne = pd.read_csv("melbourne.csv")

# %%
melbourne.info()
melbourne.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
# Suburb           23547 non-null object
# Address          23547 non-null object
# Rooms            23547 non-null int64
# Type             23547 non-null object
# Price            18396 non-null float64
# Method           23547 non-null object
# SellerG          23547 non-null object
# Date             23547 non-null object
# Distance         23546 non-null float64
# Postcode         23546 non-null float64
# Bedroom2         19066 non-null float64
# Bathroom         19063 non-null float64
# Car              18921 non-null float64
# Landsize         17410 non-null float64
# BuildingArea     10018 non-null float64
# YearBuilt        11540 non-null float64
# CouncilArea      15656 non-null object
# Lattitude        19243 non-null float64
# Longtitude       19243 non-null float64
# Regionname       23546 non-null object
# Propertycount    23546 non-null float64
# ...

# %%
melbourne.isnull()
# Out:
#       Suburb Address  Rooms   Type  Price Method SellerG   Date Distance  \
# 0      False   False  False  False   True  False   False  False    False
# 1      False   False  False  False  False  False   False  False    False
# 2      False   False  False  False  False  False   False  False    False
# 3      False   False  False  False   True  False   False  False    False
# 4      False   False  False  False  False  False   False  False    False
# 5      False   False  False  False  False  False   False  False    False
# 6      False   False  False  False  False  False   False  False    False
# 7      False   False  False  False   True  False   False  False    False
# 8      False   False  False  False   True  False   False  False    False
# 9      False   False  False  False   True  False   False  False    False
# 10     False   False  False  False  False  False   False  False    False
# 11     False   False  False  False  False  False   False  False    False
# ...

# %%
melbourne.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
melbourne.isnull().any(axis=0)
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price             True
# Method           False
# SellerG          False
# Date             False
# Distance          True
# Postcode          True
# Bedroom2          True
# Bathroom          True
# Car               True
# Landsize          True
# BuildingArea      True
# YearBuilt         True
# CouncilArea       True
# Lattitude         True
# Longtitude        True
# Regionname        True
# Propertycount     True
# dtype: bool

# %%
melbourne.isnull().any(axis=1
                    )
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14       False
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 23517     True
# 23518     True
# 23519     True
# 23520     True
# 23521     True
# 23522     True
# 23523     True
# 23524     True
# 23525     True
# 23526     True
# 23527     True
# 23528     True
# 23529     True
# 23530     True
# 23531     True
# 23532     True
# 23533     True
# 23534     True
# 23535     True
# 23536     True
# 23537     True
# 23538     True
# 23539     True
# 23540     True
# 23541     True
# 23542     True
# 23543     True
# ...

# %%
melbourne.isnull().any(axis=0)
# Out:
# Suburb           False
# Address          False
# Rooms            False
# Type             False
# Price            False
# Method           False
# SellerG          False
# Date             False
# Distance         False
# Postcode         False
# Bedroom2         False
# Bathroom         False
# Car              False
# Landsize         False
# BuildingArea     False
# YearBuilt        False
# CouncilArea      False
# Lattitude        False
# Longtitude       False
# Regionname       False
# Propertycount    False
# dtype: bool

# %%
melbourne.isnull().any(axis=1)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14       False
# 15        True
# 16        True
# 17        True
# 18       False
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 23517     True
# 23518     True
# 23519     True
# 23520     True
# 23521     True
# 23522     True
# 23523     True
# 23524     True
# 23525     True
# 23526     True
# 23527     True
# 23528     True
# 23529     True
# 23530     True
# 23531     True
# 23532     True
# 23533     True
# 23534     True
# 23535     True
# 23536     True
# 23537     True
# 23538     True
# 23539     True
# 23540     True
# 23541     True
# 23542     True
# 23543     True
# ...

# %%
len(melbourne.Suburb.unique())
# Out:
# 336

# %%
melbourne.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
by_rooms = melbourne.groupby("Rooms")

# %%
by_rooms.count()
# Out:
#        Suburb  Address   Type  Price  Method  SellerG   Date  Distance  \
# Rooms
# 1        1119     1119   1119    909    1119     1119   1119      1119
# 2        6115     6115   6115   4992    6115     6115   6115      6114
# 3       10076    10076  10076   7953   10076    10076  10076     10076
# 4        4953     4953   4953   3648    4953     4953   4953      4953
# 5        1107     1107   1107    773    1107     1107   1107      1107
# 6         133      133    133     92     133      133    133       133
# 7          19       19     19     13      19       19     19        19
# 8          14       14     14     10      14       14     14        14
# 9           4        4      4      1       4        4      4         4
# 10          5        5      5      4       5        5      5         5
# 12          2        2      2      1       2        2      2         2
#
#        Postcode  Bedroom2  Bathroom   Car  Landsize  BuildingArea  YearBuilt  \
# Rooms
# ...

# %%
by_rooms.Price.agg
# Out:
# <bound method SeriesGroupBy.aggregate of <pandas.core.groupby.SeriesGroupBy object at 0x0000029B0F422278>>

# %%
len(melbourne)
# Out:
# 23547

# %%
round(100*(melbourne.isnull().sum()/len(melbourne)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
5151/23547
# Out:
# 0.2187539813989043

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(...)
#     round(number[, ndigits]) -> number
#
#     Round a number to a given precision in decimal digits (default 0 digits).
#     This returns an int when called with one argument, otherwise the
#     same type as the number. ndigits may be negative.

# %%
melbourne = melbourne.drop("YearBuilt", axis=1);
melbourne = melbourne.drop("BuildingArea", axis=1);
melbourne = melbourne.drop("CouncilArea", axis=1);

# %%
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
melbourne[melbourne.isnull().sum(axis =1) > 5]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# 27            Abbotsford    13/84 Trenerry Cr      1    u   500000.0      S
# 33            Abbotsford     250 Langridge St      2    t   847000.0      S
# 34            Abbotsford      16b Mollison St      2    h        NaN     PI
# 45            Abbotsford    65/80 Trenerry Cr      1    u   480000.0      S
# 46            Abbotsford  119/52 Nicholson St      1    u   423500.0      S
# 52            Abbotsford    49/84 Trenerry Cr      2    h   700000.0      S
# ...

# %%
len(melbourne[melbourne.isnull().sum(axis =1) > 5].index)
# Out:
# 4278

# %%
len(melbourne[melbourne.isnull().sum(axis =1) > 5].index)/len(melbourne.index)
# Out:
# 0.1816791948018856

# %%
melbourne = melbourne[melbourne.isnull().sum(axis=1) <= 5]

# %%
len(melbourne.index)
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
melbourne = melbourne[~np.isnan(melbourne['Price'])]

# %%
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         1.05
# Bathroom         1.07
# Car              1.76
# Landsize         9.83
# Lattitude        0.15
# Longtitude       0.15
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
melbourne.Landsize.median()
# Out:
# 440.0

# %%
melbourne = melbourne[~np.isnan(melbourne['Landsize'])]

# %%
len(melbourne.index)
# Out:
# 13603

# %%
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
melbourne.loc[:, ['Bathroom', 'Car']].describe()
# Out:
#            Bathroom           Car
# count  13602.000000  13540.000000
# mean       1.534921      1.610414
# std        0.691834      0.962244
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        1.000000      2.000000
# 75%        2.000000      2.000000
# max        8.000000     10.000000

# %%
melbourne.loc

# %%
melbourne.Car.value_counts()
# Out:
# 2.0     5606
# 1.0     5515
# 0.0     1026
# 3.0      748
# 4.0      507
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: Car, dtype: int64

# %%
melbourne.Bathroom.value_counts()
# Out:
# 1.0    7517
# 2.0    4987
# 3.0     921
# 4.0     106
# 0.0      34
# 5.0      28
# 6.0       5
# 8.0       2
# 7.0       2
# Name: Bathroom, dtype: int64

# %%
melbourne["Car"] = melbourne.Car.astype("category")

# %%
melbourne.loc[pd.isnull(melbourne['Car']), ['Car']] = 2
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.00
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
melbourne.loc[np.isnan(melbourne.Lattitude), "Lattitude"] = melbourne.Lattitude.mean()
melbourne.loc[np.isnan(melbourne.Longtitude), "Longtitude"] = melbourne.Longtitude.mean()

# %%
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.00
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
melbourne["Bathroom"] = melbourne.Bathroom.astype("category")
melbourne.loc[pd.isnull(melbourne['Bathroom']), ['Bathroom']] = 1
round(100*(melbourne.isnull().sum()/len(melbourne.index)), 2)
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Price            0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# dtype: float64

# %%
melbourne.shape
# Out:
# (13603, 18)

# %%
len(melbourne.index)/23547
# Out:
# 0.5776956724848176
